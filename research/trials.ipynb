# %%
from ultralytics import settings

print("runs_dir =", settings["runs_dir"])
print("weights_dir =", settings["weights_dir"])
# Out:
# Running cells with 'Floor (3.11.9) (Python 3.11.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"d:/Adarsh/My Project Floor Plan/Project Floor Segmentation/floor-plan-segmentation/Floor/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
